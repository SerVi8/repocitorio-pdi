# %% [markdown]
# <h3>Toma de Imagenes</h3>
# <h5>Reconocimiento parte 1</h5>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.10.0

# %%
name = "nombre_persona"
paht = f'data/{name}'
os.makedirs(paht, exist_ok=True)
cap = cv2.VideoCapture(0)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cont = 0
while True:
  ret, frame = cap.read()
  if not ret:
    break
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray, 1.3,5)
  for (x, y, w, h) in faces:
    roi_gray = gray[y:y + h, x:x + w]
    roi_color = frame[y:y + h, x:x + w]
    cv2.imwrite(f'{paht}/face_{cont}.jpg', roi_gray)
    cont += 1
    cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
  cv2.imshow('Capture', frame)
  if cv2.waitKey(1) ==27 or cont >= 20:
    break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       3 os.makedirs(paht, exist_ok=True)
#       4 cap = cv2.VideoCapture(0)
# ----> 5 face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#       7 cont = 0
#       8 while True:
#
# AttributeError: module 'cv2' has no attribute 'data'
